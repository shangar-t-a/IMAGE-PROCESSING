# %% [markdown]
# ##IMPORT DATA

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Import Libraries

# %% [markdown]
# Importing necessary libraries and modules required to build the classification model.

# %%
import numpy as np
import pickle
import cv2
import os
import matplotlib.pyplot as plt
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Dataset

# %% [markdown]
# Initializing a few parameters required for the image dataset preprocessing.

# %%
# Dimension of resized image
DEFAULT_IMAGE_SIZE = tuple((256, 256))

# Number of images used to train the model
N_IMAGES = 250

# Path to the dataset folder
root_dir = '/content/gdrive/My Drive/DATASET/input_1'

train_dir = os.path.join(root_dir, 'Train')
val_dir = os.path.join(root_dir, 'Valid')

# %% [markdown]
# We use the function `convert_image_to_array` to resize an image to the size `DEFAULT_IMAGE_SIZE` we defined above.

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None:
            image = cv2.resize(image, DEFAULT_IMAGE_SIZE)   
            return img_to_array(image)
        else:
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# Here, we load the training data images by traversing through all the folders and converting all the images and labels into separate lists respectively.
#
# *NOTE: We use a small portion of the entire dataset due to the computing limitations. Tweak `N_IMAGES` to include entire dataset.*

# %%
image_list, label_list = [], []

try:
    print("[INFO] Loading images ...")
    plant_disease_folder_list = listdir(train_dir)

    for plant_disease_folder in plant_disease_folder_list:
        print(f"[INFO] Processing {plant_disease_folder} ...")
        plant_disease_image_list = listdir(f"{train_dir}/{plant_disease_folder}/")

        for image in plant_disease_image_list[:N_IMAGES]:
            image_directory = f"{train_dir}/{plant_disease_folder}/{image}"
            if image_directory.endswith(".jpg")==True or image_directory.endswith(".JPG")==True:
                image_list.append(convert_image_to_array(image_directory))
                label_list.append(plant_disease_folder)

    print("[INFO] Image loading completed")  
except Exception as e:
    print(f"Error : {e}")

# Transform the loaded training image data into numpy array
np_image_list = np.array(image_list, dtype=np.float16) / 225.0
print()

# Check the number of images loaded for training
image_len = len(image_list)
print(f"Total number of images: {image_len}")
# Out:
# [INFO] Loading images ...
# [INFO] Processing Corn_(maize)___healthy ...
# [INFO] Processing Grape___Black_rot ...
# [INFO] Processing Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot ...
# [INFO] Processing Grape___healthy ...
# [INFO] Processing Pepper,_bell___healthy ...
# [INFO] Processing Corn_(maize)___Common_rust_ ...
# [INFO] Processing Corn_(maize)___Northern_Leaf_Blight ...
# [INFO] Processing Pepper,_bell___Bacterial_spot ...
# [INFO] Processing Grape___Leaf_blight_(Isariopsis_Leaf_Spot) ...
# [INFO] Processing Grape___Esca_(Black_Measles) ...
# [INFO] Processing Tomato___Bacterial_spot ...
# [INFO] Processing Potato___healthy ...
# [INFO] Processing Potato___Late_blight ...
# [INFO] Processing Tomato___Late_blight ...
# [INFO] Processing Tomato___Early_blight ...
# [INFO] Processing Potato___Early_blight ...
# [INFO] Processing Tomato___healthy ...
# [INFO] Image loading completed
#
# Total number of images: 1700

# %% [markdown]
# Examine the labels/classes in the training dataset.

# %%
label_binarizer = LabelBinarizer()
image_labels = label_binarizer.fit_transform(label_list)

pickle.dump(label_binarizer,open('plant_disease_label_transform.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

print("Total number of classes: ", n_classes)
# Out:
# Total number of classes:  17

# %% [markdown]
# # Augment and Split Dataset

# %% [markdown]
# Using `ImageDataGenerator` to augment data by performing various operations on the training images.

# %%
augment = ImageDataGenerator(rotation_range=25, width_shift_range=0.1,
                             height_shift_range=0.1, shear_range=0.2, 
                             zoom_range=0.2, horizontal_flip=True, 
                             fill_mode="nearest")

# %% [markdown]
# Splitting the data into training and test sets for validation purpose.

# %%
x_train = 
x_test = 
y_train =
y_test =

# %%
print("[INFO] Splitting data to train and test...")
x_train, x_test, y_train, y_test = train_test_split(np_image_list, image_labels, test_size=0.2, random_state = 42)
# Out:
# [INFO] Splitting data to train and test...

# %% [markdown]
# # Build Model

# %% [markdown]
# Defining the hyperparameters of the plant disease classification model.

# %%
EPOCHS = 25
STEPS = 100
LR = 1e-3
BATCH_SIZE = 32
WIDTH = 256
HEIGHT = 256
DEPTH = 3

# %% [markdown]
# Creating a sequential model and adding Convolutional, Normalization, Pooling, Dropout and Activation layers at the appropriate positions.

# %%
model = Sequential()
inputShape = (HEIGHT, WIDTH, DEPTH)
chanDim = -1

if K.image_data_format() == "channels_first":
    inputShape = (DEPTH, HEIGHT, WIDTH)
    chanDim = 1

model.add(Conv2D(32, (3, 3), padding="same",input_shape=inputShape))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(64, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(Conv2D(128, (3, 3), padding="same"))
model.add(Activation("relu"))
model.add(BatchNormalization(axis=chanDim))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation("relu"))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(n_classes))
model.add(Activation("softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      896
# _________________________________________________________________
# activation (Activation)      (None, 256, 256, 32)      0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 85, 85, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 85, 85, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 85, 85, 64)        18496
# _________________________________________________________________
# activation_1 (Activation)    (None, 85, 85, 64)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 85, 85, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 85, 85, 64)        36928
# _________________________________________________________________
# activation_2 (Activation)    (None, 85, 85, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 85, 85, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 42, 42, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 42, 42, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 42, 42, 128)       73856
# _________________________________________________________________
# activation_3 (Activation)    (None, 42, 42, 128)       0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 42, 42, 128)       512
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 42, 42, 128)       147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 42, 42, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 42, 42, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 21, 21, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 56448)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              57803776
# _________________________________________________________________
# activation_5 (Activation)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 17)                17425
# _________________________________________________________________
# activation_6 (Activation)    (None, 17)                0
# =================================================================
# Total params: 58,104,721
# Trainable params: 58,101,841
# Non-trainable params: 2,880
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %% [markdown]
# We initialize Adam optimizer with learning rate and decay parameters.
#
# Also, we choose the type of loss and metrics for the model and compile it for training.

# %%
# Initialize optimizer
opt = Adam(lr=LR, decay=LR / EPOCHS)

# Compile model
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])

# Train model
print("[INFO] Training network...")
history = model.fit_generator(augment.flow(x_train, y_train, batch_size=BATCH_SIZE),
                              validation_data=(x_test, y_test),
                              steps_per_epoch=len(x_train) // BATCH_SIZE,
                              epochs=EPOCHS, 
                              verbose=1)
# Out:
# [INFO] Training network...
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/25
# 42/42 [==============================] - 292s 7s/step - loss: 0.8371 - accuracy: 0.2050 - val_loss: 0.5220 - val_accuracy: 0.0265
# Epoch 2/25
# 42/42 [==============================] - 287s 7s/step - loss: 0.4589 - accuracy: 0.2929 - val_loss: 0.3061 - val_accuracy: 0.0647
# Epoch 3/25
# 42/42 [==============================] - 286s 7s/step - loss: 0.2172 - accuracy: 0.3715 - val_loss: 0.4886 - val_accuracy: 0.0853
# Epoch 4/25
# 42/42 [==============================] - 287s 7s/step - loss: 0.1687 - accuracy: 0.5116 - val_loss: 0.5433 - val_accuracy: 0.0618
# Epoch 5/25
# 42/42 [==============================] - 288s 7s/step - loss: 0.1454 - accuracy: 0.5481 - val_loss: 0.5704 - val_accuracy: 0.0500
# Epoch 6/25
# 42/42 [==============================] - 287s 7s/step - loss: 0.1217 - accuracy: 0.6432 - val_loss: 0.6305 - val_accuracy: 0.0824
# Epoch 7/25
# 42/42 [==============================] - 286s 7s/step - loss: 0.1087 - accuracy: 0.6666 - val_loss: 0.5385 - val_accuracy: 0.1500
# Epoch 8/25
# 42/42 [==============================] - 287s 7s/step - loss: 0.1053 - accuracy: 0.7077 - val_loss: 0.4470 - val_accuracy: 0.1265
# Epoch 9/25
# 42/42 [==============================] - 287s 7s/step - loss: 0.0893 - accuracy: 0.7480 - val_loss: 0.3409 - val_accuracy: 0.1971
# Epoch 10/25
# 42/42 [==============================] - 289s 7s/step - loss: 0.0824 - accuracy: 0.7900 - val_loss: 0.4360 - val_accuracy: 0.3971
# Epoch 11/25
# 42/42 [==============================] - 289s 7s/step - loss: 0.1701 - accuracy: 0.6511 - val_loss: 0.8619 - val_accuracy: 0.2559
# Epoch 12/25
# 42/42 [==============================] - 287s 7s/step - loss: 0.1552 - accuracy: 0.6147 - val_loss: 0.9306 - val_accuracy: 0.1147
# Epoch 13/25
# 42/42 [==============================] - 288s 7s/step - loss: 0.1262 - accuracy: 0.7011 - val_loss: 0.1674 - val_accuracy: 0.5382
# Epoch 14/25
# 42/42 [==============================] - 290s 7s/step - loss: 0.0997 - accuracy: 0.7237 - val_loss: 0.1619 - val_accuracy: 0.5412
# Epoch 15/25
# 42/42 [==============================] - 289s 7s/step - loss: 0.1014 - accuracy: 0.7579 - val_loss: 0.1177 - val_accuracy: 0.6412
# Epoch 16/25
# 42/42 [==============================] - 288s 7s/step - loss: 0.0780 - accuracy: 0.8179 - val_loss: 0.0717 - val_accuracy: 0.7588
# Epoch 17/25
# 42/42 [==============================] - 288s 7s/step - loss: 0.0882 - accuracy: 0.7785 - val_loss: 0.4068 - val_accuracy: 0.3735
# Epoch 18/25
# 42/42 [==============================] - 289s 7s/step - loss: 0.0991 - accuracy: 0.7341 - val_loss: 0.1222 - val_accuracy: 0.6853
# Epoch 19/25
# 42/42 [==============================] - 288s 7s/step - loss: 0.0846 - accuracy: 0.8038 - val_loss: 0.1244 - val_accuracy: 0.6647
# Epoch 20/25
# 42/42 [==============================] - 291s 7s/step - loss: 0.0735 - accuracy: 0.8235 - val_loss: 0.1221 - val_accuracy: 0.6471
# Epoch 21/25
# 42/42 [==============================] - 289s 7s/step - loss: 0.0649 - accuracy: 0.8423 - val_loss: 0.1206 - val_accuracy: 0.6794
# Epoch 22/25
# 42/42 [==============================] - 289s 7s/step - loss: 0.0646 - accuracy: 0.8573 - val_loss: 0.1088 - val_accuracy: 0.6941
# Epoch 23/25
# 42/42 [==============================] - 286s 7s/step - loss: 0.0599 - accuracy: 0.8704 - val_loss: 0.1071 - val_accuracy: 0.6853
# Epoch 24/25
# 42/42 [==============================] - 286s 7s/step - loss: 0.0587 - accuracy: 0.8707 - val_loss: 0.1136 - val_accuracy: 0.6912
# Epoch 25/25
# 42/42 [==============================] - 287s 7s/step - loss: 0.0561 - accuracy: 0.8664 - val_loss: 0.0569 - val_accuracy: 0.8353

# %% [markdown]
# # Evaluate Model

# %% [markdown]
# Comparing the accuracy and loss by plotting the graph for training and validation.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

# Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()

# Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %% [markdown]
# Evaluating model accuracy by using the `evaluate` method

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 11/11 [==============================] - 15s 1s/step - loss: 0.0569 - accuracy: 0.8353
# Test Accuracy: 83.52941274642944

# %% [markdown]
# # Save Model

# %%
# Dump pickle file of the model
print("[INFO] Saving model...")
pickle.dump(model,open('plant_disease_classification_model.pkl', 'wb'))
# Out:
# [INFO] Saving model...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-428629a789f3> in <module>()
#       1 # Dump pickle file of the model
#       2 print("[INFO] Saving model...")
# ----> 3 pickle.dump(model,open('plant_disease_classification_model.pkl', 'wb'))
#
# TypeError: can't pickle weakref objects

# %%
from keras.models import load_model
model.save('my_model.h5')

# %%
model = load_model('my_model.h5')

# %%
# Dump pickle file of the labels
print("[INFO] Saving label transform...")
filename = 'plant_disease_label_transform.pkl'
image_labels = pickle.load(open(filename, 'rb'))
# Out:
# [INFO] Saving label transform...

# %% [markdown]
# # Test Model

# %% [markdown]
# We write the following `predict_disease` function to predict the class or disease of a plant image.
#
# We just need to provide the complete path to the image and it displays the image along with its prediction class or plant disease.

# %%
def predict_disease(image_path):
    image_array = convert_image_to_array(image_path)
    np_image = np.array(image_array, dtype=np.float16) / 225.0
    np_image = np.expand_dims(np_image,0)
    plt.imshow(plt.imread(image_path))
    result = model.predict_classes(np_image)
    print((image_labels.classes_[result][0]))

# %% [markdown]
# For testing purposes, we randomly choose images from the dataset and try predicting class or disease of the plant image.

# %%
predict_disease('/content/gdrive/My Drive/DATASET/input_1/Train/Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot/0a403456-5c5e-4aad-aa89-a118175c6ddd___RS_GLSp 4501_270deg.JPG')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot

# %%
predict_disease('/content/PlantVillage/val/Potato___Early_blight/03b0d3c1-b5b0-48f4-98aa-f8904670290f___RS_Early.B 7051.JPG')
# Out:
# Potato___Early_blight

# %%
predict_disease('/content/PlantVillage/val/Tomato___Target_Spot/1006b3dd-22d8-41b8-b83d-08bf189fcdaa___Com.G_TgS_FL 8118.JPG')
# Out:
# Tomato___Target_Spot

# %%
predict_disease('/content/PlantVillage/val/Orange___Haunglongbing_(Citrus_greening)/02459e0c-a189-4dc9-a0dc-0548e36d0efb___CREC_HLB 5714.JPG')
# Out:
# Orange___Haunglongbing_(Citrus_greening)

# %% [markdown]
# # Reuse Model

# %% [markdown]
# We download the trained model and label transform saved in the Google Drive.

# %%
# Download the trained model file based on its file ID.
file_id = '1E5jNzpM__7z67GRl1cbhHK71yKcPa8wl'
# !gdown https://drive.google.com/uc?id={file_id}

# Download the labels file based on its file ID.
file_id = '1WsgEd3TG33Vj_9AAAT_WfJe_AqsuC9uu'
# !gdown https://drive.google.com/uc?id={file_id}
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1E5jNzpM__7z67GRl1cbhHK71yKcPa8wl
# To: /content/plant_disease_classification_model.pkl
# 698MB [00:04, 162MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WsgEd3TG33Vj_9AAAT_WfJe_AqsuC9uu
# To: /content/plant_disease_label_transform.pkl
# 100% 8.18k/8.18k [00:00<00:00, 8.17MB/s]

# %% [markdown]
# Importing necessary libraries and modules required to build the classification model.

# %%
import numpy as np
import pickle
import cv2
import os
import matplotlib.pyplot as plt
from os import listdir
from sklearn.preprocessing import LabelBinarizer
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation, Flatten, Dropout, Dense
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# Load the trained model and its labels for prediction.

# %%
# Load model
filename = '/content/gdrive/plant_disease_classification_model.pkl'
model = pickle.load(open(filename, 'rb'))

# Load labels
filename = '/content/gdrive/plant_disease_label_transform.pkl'
image_labels = pickle.load(open(filename, 'rb'))

# %% [markdown]
# We use the `convert_image_to_array` function to resize an image and `predict_disease` function to predict the class or disease of a plant image.
#
# We just need to provide the complete path to the image and it displays the image along with its prediction class or plant disease.

# %%
# Dimension of resized image
DEFAULT_IMAGE_SIZE = tuple((256, 256))

def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None:
            image = cv2.resize(image, DEFAULT_IMAGE_SIZE)   
            return img_to_array(image)
        else:
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

def predict_disease(image_path):
    image_array = convert_image_to_array(image_path)
    np_image = np.array(image_array, dtype=np.float16) / 225.0
    np_image = np.expand_dims(np_image,0)
    plt.imshow(plt.imread(image_path))
    result = model.predict_classes(np_image)
    print((image_labels.classes_[result][0]))

# %% [markdown]
# Predict disease of any plant image.

# %%
predict_disease('/content/gdrive/My Drive/DATASET/input_1/Valid/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)/0b267a2e-c32d-47cd-8494-efc12a326493___FAM_L.Blight 0815_flipLR(1).JPG')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-e72568a4512a> in <module>()
# ----> 1 predict_disease('/content/gdrive/My Drive/DATASET/input_1/Valid/Grape___Leaf_blight_(Isariopsis_Leaf_Spot)/0b267a2e-c32d-47cd-8494-efc12a326493___FAM_L.Blight 0815_flipLR(1).JPG')
#
# <ipython-input-17-808bdf5155eb> in predict_disease(image_path)
#      20     plt.imshow(plt.imread(image_path))
#      21     result = model.predict_classes(np_image)
# ---> 22     print((image_labels.classes_[result][0]))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'classes_'
